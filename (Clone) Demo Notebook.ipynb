# %%
print ("hello world")

# %%
# %sql
select "hi from SQL"

# %% [markdown]
# #Title 1
# ##Title 2
# ### Title 3

# %%
# %run /Workspace/Reference/Lookup

# %%
print(name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.fs.ls('/databricks-datasets')

# %%
files=dbutils.fs.ls('/databricks-datasets')
display(files)

# %% [markdown]
# #Title 2
